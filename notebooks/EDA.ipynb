# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (6.23.2)
# Requirement already satisfied: comm>=0.1.1 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: psutil in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: traitlets>=5.4.0 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (8.12.2)
# Requirement already satisfied: pyzmq>=20 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (25.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: nest-asyncio in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (5.3.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (8.2.0)
# Requirement already satisfied: packaging in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (23.1)
# Requirement already satisfied: tornado>=6.1 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: stack-data in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: colorama in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: pickleshare in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: backcall in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: typing-extensions in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: decorator in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (6.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.5.3)
# Requirement already satisfied: pywin32>=300 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: zipp>=0.5 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: pure-eval in d:\ml bootcamp\oibsip-car-price-prediction\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#data ingestion step
data = pd.read_csv("data/test.csv")
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
#making a copy of the data set so that it do not harm the original dataset.
df = data.copy()
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 200       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#lets drop the "car_id, carname, symboling, enginelocation and doornumber" column cause it is of less use.
df=df.drop(labels=['car_ID','CarName', 'symboling', 'doornumber', 'enginelocation'],axis=1)
df.head()
# Out:
#   fueltype aspiration      carbody drivewheel  wheelbase  carlength  carwidth  \
# 0      gas        std  convertible        rwd       88.6      168.8      64.1
# 1      gas        std  convertible        rwd       88.6      168.8      64.1
# 2      gas        std    hatchback        rwd       94.5      171.2      65.5
# 3      gas        std        sedan        fwd       99.8      176.6      66.2
# 4      gas        std        sedan        4wd       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ... enginesize  fuelsystem boreratio  \
# 0       48.8        2548       dohc  ...        130        mpfi      3.47
# 1       48.8        2548       dohc  ...        130        mpfi      3.47
# 2       52.4        2823       ohcv  ...        152        mpfi      2.68
# 3       54.3        2337        ohc  ...        109        mpfi      3.19
# 4       54.3        2824        ohc  ...        136        mpfi      3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 0    2.68               9.0         111     5000       21          27  13495.0
# 1    2.68               9.0         111     5000       21          27  16500.0
# 2    3.47               9.0         154     5000       19          26  16500.0
# 3    3.40              10.0         102     5500       24          30  13950.0
# 4    3.40               8.0         115     5500       18          22  17450.0
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (205, 21)

# %%
#now we will check for the null values
df.isnull().sum()
# Out:
# fueltype            0
# aspiration          0
# carbody             0
# drivewheel          0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
## our dataset has no null values and we are good to go now

# %%
## now we will check for duplicated values
df.duplicated().sum()
# Out:
# 1

# %%
#dropping the duplicated values.
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#this features need to be changed cause we need numerical values but the number names are written
df = df.replace({'cylindernumber':{'four':4 , 'six':6 , 'five':5 , 'three':3 , 'twelve':12 , 'two':2 ,'eight':8}})
df['cylindernumber']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 200    4
# 201    4
# 202    6
# 203    6
# 204    4
# Name: cylindernumber, Length: 204, dtype: int64

# %%
## segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'cylindernumber', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')
# Categorical Columns: Index(['fueltype', 'aspiration', 'carbody', 'drivewheel', 'enginetype',
#        'fuelsystem'],
#       dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#        fueltype aspiration carbody drivewheel enginetype fuelsystem
# count       204        204     204        204        204        204
# unique        2          2       5          3          7          8
# top         gas        std   sedan        fwd        ohc       mpfi
# freq        184        167      96        119        147         94

# %%
df['fueltype'].value_counts()
# Out:
# fueltype
# gas       184
# diesel     20
# Name: count, dtype: int64

# %%
df['aspiration'].value_counts()
# Out:
# aspiration
# std      167
# turbo     37
# Name: count, dtype: int64

# %%
df['carbody'].value_counts()
# Out:
# carbody
# sedan          96
# hatchback      69
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
df['drivewheel'].value_counts()
# Out:
# drivewheel
# fwd    119
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
df['enginetype'].value_counts()
# Out:
# enginetype
# ohc      147
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64

# %%
df['fuelsystem'].value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    65
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## correlation
sns.heatmap(df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 ## correlation
# ----> 2 sns.heatmap(df.corr(),annot=True)
#
# File d:\ML Bootcamp\OIBSIP-Car-Price-Prediction\venv\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File d:\ML Bootcamp\OIBSIP-Car-Price-Prediction\venv\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File d:\ML Bootcamp\OIBSIP-Car-Price-Prediction\venv\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File d:\ML Bootcamp\OIBSIP-Car-Price-Prediction\venv\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'gas'

# %%
#we can observe that carlength is very much corelated to the wheelbase,carwidth,curbweight
# and curb weight in the same manner also corelated to the enginesize
#but we will not drop these features as of now cause if we have more features then we build a very good model.

# %%
df.head()
# Out:
#   fueltype aspiration      carbody drivewheel  wheelbase  carlength  carwidth  \
# 0      gas        std  convertible        rwd       88.6      168.8      64.1
# 1      gas        std  convertible        rwd       88.6      168.8      64.1
# 2      gas        std    hatchback        rwd       94.5      171.2      65.5
# 3      gas        std        sedan        fwd       99.8      176.6      66.2
# 4      gas        std        sedan        4wd       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ...  enginesize  fuelsystem boreratio  \
# 0       48.8        2548       dohc  ...         130        mpfi      3.47
# 1       48.8        2548       dohc  ...         130        mpfi      3.47
# 2       52.4        2823       ohcv  ...         152        mpfi      2.68
# 3       54.3        2337        ohc  ...         109        mpfi      3.19
# 4       54.3        2824        ohc  ...         136        mpfi      3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 0    2.68               9.0         111     5000       21          27  13495.0
# 1    2.68               9.0         111     5000       21          27  16500.0
# 2    3.47               9.0         154     5000       19          26  16500.0
# 3    3.40              10.0         102     5500       24          30  13950.0
# 4    3.40               8.0         115     5500       18          22  17450.0
#
# [5 rows x 21 columns]

# %%
df[categorical_columns]
# Out:
#     fueltype aspiration      carbody drivewheel enginetype fuelsystem
# 0        gas        std  convertible        rwd       dohc       mpfi
# 1        gas        std  convertible        rwd       dohc       mpfi
# 2        gas        std    hatchback        rwd       ohcv       mpfi
# 3        gas        std        sedan        fwd        ohc       mpfi
# 4        gas        std        sedan        4wd        ohc       mpfi
# ..       ...        ...          ...        ...        ...        ...
# 200      gas        std        sedan        rwd        ohc       mpfi
# 201      gas      turbo        sedan        rwd        ohc       mpfi
# 202      gas        std        sedan        rwd       ohcv       mpfi
# 203   diesel      turbo        sedan        rwd        ohc        idi
# 204      gas      turbo        sedan        rwd        ohc       mpfi
#
# [204 rows x 6 columns]

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df['drivewheel'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
fueltype_map = {'diesel':1, 'gas':2}

# %%
aspiration_map = {'std':1,'turbo':2}

# %%
carbody_map = {"hatchback":1, "sedan":2, "wagon":3, "convertible":4, "hardtop":5}

# %%
drivewheel_map = {"fwd":1, "4wd":2, "rwd":3}

# %%
enginetype_map = {"ohc":1, "l":2, 'ohcf':3, 'doch':4, "ohcv":5, "rotor":6, "dohcv":7}

# %%
fuelsystem_map = {
"1bbl": 1,
"2bbl": 2,
"4bbl": 3,
"spfi": 4,
"mpfi": 5,
"spdi": 6,
"mfi": 7,
"idi": 8
}

# %%
df['fueltype']=df['fueltype'].map(fueltype_map)
df['aspiration']=df['aspiration'].map(aspiration_map)
df['carbody']=df['carbody'].map(carbody_map)
df['drivewheel']=df['drivewheel'].map(drivewheel_map)
df['enginetype']=df['enginetype'].map(enginetype_map)
df['fuelsystem']=df['fuelsystem'].map(fuelsystem_map)

# %%
df.head()
# Out:
#    fueltype  aspiration  carbody  drivewheel  wheelbase  carlength  carwidth  \
# 0         2           1        4           3       88.6      168.8      64.1
# 1         2           1        4           3       88.6      168.8      64.1
# 2         2           1        1           3       94.5      171.2      65.5
# 3         2           1        2           1       99.8      176.6      66.2
# 4         2           1        2           2       99.4      176.6      66.4
#
#    carheight  curbweight  enginetype  ...  enginesize  fuelsystem  boreratio  \
# 0       48.8        2548         NaN  ...         130           5       3.47
# 1       48.8        2548         NaN  ...         130           5       3.47
# 2       52.4        2823         5.0  ...         152           5       2.68
# 3       54.3        2337         1.0  ...         109           5       3.19
# 4       54.3        2824         1.0  ...         136           5       3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 0    2.68               9.0         111     5000       21          27  13495.0
# 1    2.68               9.0         111     5000       21          27  16500.0
# 2    3.47               9.0         154     5000       19          26  16500.0
# 3    3.40              10.0         102     5500       24          30  13950.0
# 4    3.40               8.0         115     5500       18          22  17450.0
#
# [5 rows x 21 columns]
